# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravlochab/NLP-huggingface/blob/main/Course_HF_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install datasets evaluate transformers

# %%
#pipeline

from transformers import pipeline 

classifier = pipeline('zero-shot-classification')
classifier("let's do NLP",candidate_labels = ["education","politics"],)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': "let's do NLP",
#  'labels': ['education', 'politics'],
#  'scores': [0.9159495830535889, 0.08405036479234695]}

# %%
# An example of a task is predicting the next word in a sentence
# having read the n previous words. 
# This is called causal language modeling because the output depends on the past 
# and present inputs,
# but not the future ones

# Another example is masked language modeling,
# in which the model predicts a masked word in the sentence
